# %%
import xarray as xr
import torch 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DEFAULT_INPUT_DIR = Path("../output/raw_datasets/")
FILE_NAME = Path("raw_nwp_dataset.nc")

ds = xr.open_dataset(DEFAULT_INPUT_DIR / FILE_NAME)

ds
# Out:
# <xarray.Dataset> Size: 11GB
# Dimensions:     (time: 8736, channel: 7, lat: 104, lon: 225)
# Coordinates:
#   * time        (time) datetime64[ns] 70kB 2025-01-02 ... 2025-12-31T23:00:00
#     issue_date  (time) datetime64[ns] 70kB ...
#   * channel     (channel) <U4 112B 'ghi' 'sp' 't2m' 'tcc' 'tp' 'u100' 'v100'
#   * lat         (lat) float64 832B 46.5 46.4 46.3 46.2 ... 36.5 36.4 36.3 36.2
#   * lon         (lon) float64 2kB 96.1 96.2 96.3 96.4 ... 118.3 118.4 118.5
# Data variables:
#     cube        (time, channel, lat, lon) float64 11GB ...
# Attributes:
#     time_alignment_rule:  time = filename issue_date + 1 day + original lead_...
#     note:                 lead_time dimension removed; folded into time coord...

# %%
colorscale = "Spectral_r"

# %%
map = ds.cube.isel(channel=3).mean(dim="lon").mean(dim="lat").plot()
